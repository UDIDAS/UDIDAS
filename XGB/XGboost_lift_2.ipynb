# %%
import pandas as pd

# %%
dfx=pd.read_csv('C:/Users/udipt/Desktop/Websoft/Performance/Independent_vars.csv')
dfy=pd.read_csv('C:/Users/udipt/Desktop/Websoft/Performance/Comparison.csv')

# %%
dfx.head()
# Out:
#    Unnamed: 0  sl_number      ID  event_timestamp  log_timestamp  \
# 0           0      13877  549783       1594922787     1437030415
# 1           1       6815   95321       1359908656     1434251185
# 2           2       9851  724307       1473380907     1435461182
# 3           3      16012  702211       1441476449     1437718017
# 4           4        130  709365       1431615901     1432285540
#
#    log_reading_1  log_reading_3  log_reading_4  Type_TypeA  Type_TypeB  \
# 0             10             10              6           0           1
# 1             10             10              6           0           1
# 2             10              6              8           1           0
# 3             10             10              7           1           0
# 4             10             10             10           1           0
#
#    log_reading_2_a  log_reading_2_b  log_reading_2_c  warranty_service_flag_y
# ...

# %%
dfy.head()
# Out:
#    Unnamed: 0  predicted_probabilities  actual_values  decile_rank
# 0        1866                 0.998291              1            9
# 1        1420                 0.997538              1            9
# 2         634                 0.997482              0            9
# 3         278                 0.997222              1            9
# 4        1798                 0.996950              1            9

# %%
final_df=pd.merge(left=dfx,right=dfy,left_on='Unnamed: 0',right_on='Unnamed: 0')

# %%
final_df.head()
# Out:
#    Unnamed: 0  sl_number      ID  event_timestamp  log_timestamp  \
# 0           0      13877  549783       1594922787     1437030415
# 1           1       6815   95321       1359908656     1434251185
# 2           2       9851  724307       1473380907     1435461182
# 3           3      16012  702211       1441476449     1437718017
# 4           4        130  709365       1431615901     1432285540
#
#    log_reading_1  log_reading_3  log_reading_4  Type_TypeA  Type_TypeB  \
# 0             10             10              6           0           1
# 1             10             10              6           0           1
# 2             10              6              8           1           0
# 3             10             10              7           1           0
# 4             10             10             10           1           0
#
#    log_reading_2_a  log_reading_2_b  log_reading_2_c  warranty_service_flag_y  \
# ...

# %%
final_df=final_df.drop(columns='Unnamed: 0')
final_df.columns
# Out:
# Index(['sl_number', 'ID', 'event_timestamp', 'log_timestamp', 'log_reading_1',
#        'log_reading_3', 'log_reading_4', 'Type_TypeA', 'Type_TypeB',
#        'log_reading_2_a', 'log_reading_2_b', 'log_reading_2_c',
#        'warranty_service_flag_y', 'predicted_probabilities', 'actual_values',
#        'decile_rank'],
#       dtype='object')

# %%
final_df.sort_values('predicted_probabilities',ascending=False)
# Out:
#       sl_number      ID  event_timestamp  log_timestamp  log_reading_1  \
# 1866       2577  320491       1600747211     1432962455             10
# 1420       8617  567347       1600747211     1435046916              9
# 634        5779  710785       1600735958     1433923795              8
# 278       13849  641089       1600747211     1437023295             10
# 1798       3802  711257       1600747211     1433311598              1
# ...         ...     ...              ...            ...            ...
# 3036      14171  769893       1436997274     1437116740             10
# 503        9759  754589       1435352232     1435482678             10
# 2241      11757  762451       1436126707     1436170482             10
# 177        9846  752283       1435450389     1435544096             10
# 1594      15766  759339       1435955279     1437894414             10
#
#       log_reading_3  log_reading_4  Type_TypeA  Type_TypeB  log_reading_2_a  \
# ...

# %%
final_df.groupby('decile_rank')[final_df.columns].mean()
# Out:
#                sl_number             ID  event_timestamp  log_timestamp  \
# decile_rank
# 0            8627.860412  541447.196796     1.414745e+09   1.435005e+09
# 1            8125.717890  564913.885321     1.416514e+09   1.434857e+09
# 2            7754.513761  542776.972477     1.417162e+09   1.434759e+09
# 3            7998.338673  512255.787185     1.423839e+09   1.434851e+09
# 4            8054.958716  450233.050459     1.456529e+09   1.434883e+09
# 5            8244.899314  459465.471396     1.482170e+09   1.434937e+09
# 6            8216.369266  460811.325688     1.489761e+09   1.434909e+09
# 7            7688.660550  487115.412844     1.494592e+09   1.434726e+09
# 8            7856.403670  496523.788991     1.506258e+09   1.434749e+09
# 9            8414.597254  551285.137300     1.525076e+09   1.434980e+09
#
#              log_reading_1  log_reading_3  log_reading_4  Type_TypeA  \
# decile_rank
# 0                 9.272311       9.372998       5.844394    0.496568
# ...

# %%
l=[]
for i in final_df.columns:
    if i!='sl_number' and i!='ID' and i!='decile_rank':
        l.append(i)

# %%
final_df.groupby('decile_rank')[l].mean()
# Out:
#              event_timestamp  log_timestamp  log_reading_1  log_reading_3  \
# decile_rank
# 0               1.414745e+09   1.435005e+09       9.272311       9.372998
# 1               1.416514e+09   1.434857e+09       9.256881       9.325688
# 2               1.417162e+09   1.434759e+09       9.137615       9.282110
# 3               1.423839e+09   1.434851e+09       9.032037       9.089245
# 4               1.456529e+09   1.434883e+09       8.899083       9.121560
# 5               1.482170e+09   1.434937e+09       8.935927       9.162471
# 6               1.489761e+09   1.434909e+09       9.073394       9.213303
# 7               1.494592e+09   1.434726e+09       9.089450       9.261468
# 8               1.506258e+09   1.434749e+09       9.160550       9.240826
# 9               1.525076e+09   1.434980e+09       8.759725       8.894737
#
#              log_reading_4  Type_TypeA  Type_TypeB  log_reading_2_a  \
# decile_rank
# ...

# %% [markdown]
# ## from above output, it seems that event_timestamp and log_reading_4 have significant impact on the target variable
